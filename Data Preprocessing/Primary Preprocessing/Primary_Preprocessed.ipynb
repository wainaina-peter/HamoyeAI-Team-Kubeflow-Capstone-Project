# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/lower secondary final.csv")

# %%
df.head()
# Out:
#    Unnamed: 0             Region     Country  Year  Gender  \
# 0           0  SDG: Central Asia  Kazakhstan  2012  female
# 1           1  SDG: Central Asia  Kazakhstan  2012    male
# 2           2  SDG: Central Asia  Kazakhstan  2013  female
# 3           3  SDG: Central Asia  Kazakhstan  2013    male
# 4           4  SDG: Central Asia  Kazakhstan  2014  female
#
#    Completion rate, lower secondary education,  \
# 0                                         99.6
# 1                                         99.3
# 2                                         99.6
# 3                                         99.4
# 4                                         99.6
#
#    Gross enrolment ratio, early childhood education,  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              36.65
#
#    Gross enrolment ratio, early childhood educational development programmes,  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    Gross intake ratio to the last grade of lower secondary general education,  \
# 0                                              96.64
# 1                                              97.66
# 2                                             103.13
# 3                                             102.95
# 4                                             105.74
#
#    Literacy rate, population 25-64 years,  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    Percentage of children under 5 years experiencing positive and stimulating home learning environments,  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percentage of students in lower secondary education who have their first or home language as language of instruction,  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percentage of teachers in lower secondary education who received in-service training in the last 12 months by type of training,  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Teacher attrition rate from lower secondary education,  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Existence of funding mechanisms to reallocate education resources to disadvantaged populations  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Expenditure on education as a percentage of total government expenditure (%)  \
# 0                                              19.25
# 1                                              19.25
# 2                                              17.96
# 3                                              17.96
# 4                                              17.32
#
#    Government expenditure on education as a percentage of GDP (%)
# 0                                               3.90
# 1                                               3.90
# 2                                               3.44
# 3                                               3.44
# 4                                               3.42

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                            0
# Region                                                                                                                                0
# Country                                                                                                                               0
# Year                                                                                                                                  0
# Gender                                                                                                                                0
# Completion rate, lower secondary education,                                                                                         738
# Gross enrolment ratio, early childhood education,                                                                                   992
# Gross enrolment ratio, early childhood educational development programmes,                                                          388
# Gross intake ratio to the last grade of lower secondary general education,                                                         1003
# Literacy rate, population 25-64 years,                                                                                             1940
# Percentage of children under 5 years experiencing positive and stimulating home learning environments,                             2490
# Percentage of students in lower secondary education who have their first or home language as language of instruction,              2468
# Percentage of teachers in lower secondary education who received in-service training in the last 12 months by type of training,    2512
# Teacher attrition rate from lower secondary education,                                                                             2456
# Existence of funding mechanisms to reallocate education resources to disadvantaged populations                                     2470
# Expenditure on education as a percentage of total government expenditure (%)                                                        650
# Government expenditure on education as a percentage of GDP (%)                                                                      596
# dtype: int64

# %%
df2 = df[~df.Year.isin([2022])]
#Excluding the year '2022' from the dataset

# %% [markdown]
# **Percentage of Missing Data**

# %%
round((df2.isnull().sum()/len(df2) *100), 2)
# Out:
# Unnamed: 0                                                                                                                          0.00
# Region                                                                                                                              0.00
# Country                                                                                                                             0.00
# Year                                                                                                                                0.00
# Gender                                                                                                                              0.00
# Completion rate, lower secondary education,                                                                                        24.58
# Gross enrolment ratio, early childhood education,                                                                                  35.70
# Gross enrolment ratio, early childhood educational development programmes,                                                         15.47
# Gross intake ratio to the last grade of lower secondary general education,                                                         36.30
# Literacy rate, population 25-64 years,                                                                                             73.01
# Percentage of children under 5 years experiencing positive and stimulating home learning environments,                             95.17
# Percentage of students in lower secondary education who have their first or home language as language of instruction,              94.28
# Percentage of teachers in lower secondary education who received in-service training in the last 12 months by type of training,    96.05
# Teacher attrition rate from lower secondary education,                                                                             93.96
# Existence of funding mechanisms to reallocate education resources to disadvantaged populations                                     94.36
# Expenditure on education as a percentage of total government expenditure (%)                                                       23.61
# Government expenditure on education as a percentage of GDP (%)                                                                     19.34
# dtype: float64

# %% [markdown]
# It's observed that about 17% of the dataset didnt have value for the target variable(Completion rate, lower secondary education,).Let's see the names of those countries that didn't have velues for the target variable

# %%
null_mask= df['Completion rate, lower secondary education,'].isnull()
null_rows= df.loc[null_mask]
null_countries= null_rows.Country
print("About",null_countries.nunique(), "countries didnt have the target variable")
print("The name of those countries are :", null_countries.unique())
# Out:
# About 94 countries didnt have the target variable
# The name of those countries are : ['Tajikistan' 'Turkmenistan' 'Uzbekistan' 'Afghanistan' 'Bangladesh'
#  'Bhutan' 'India' 'Maldives' 'Nepal' 'Pakistan' 'Sri Lanka' 'Cambodia'
#  'China' 'Malaysia' 'Mongolia' 'Philippines' 'Thailand' 'Timor-Leste'
#  'Albania' 'Belarus' 'Bosnia and Herzegovina' 'Montenegro' 'Serbia'
#  'Ukraine' 'Antigua and Barbuda' 'Belize' 'Chile' 'Cuba' 'Dominica'
#  'Ecuador' 'El Salvador' 'Grenada' 'Guatemala' 'Guyana' 'Honduras'
#  'Jamaica' 'Nicaragua' 'Panama' 'Suriname' 'Algeria' 'Armenia'
#  'Azerbaijan' 'Georgia' 'Jordan' 'Lebanon' 'Libya' 'Morocco'
#  'Syrian Arab Republic' 'Tunisia' 'Fiji' 'Kiribati' 'Marshall Islands'
#  'Palau' 'Samoa' 'Solomon Islands' 'Tonga' 'Tuvalu' 'Vanuatu' 'Angola'
#  'Benin' 'Botswana' 'Burkina Faso' 'Burundi' 'Cameroon'
#  'Central African Republic' 'Chad' 'Comoros' 'Djibouti' 'Eritrea'
#  'Ethiopia' 'Gabon' 'Gambia' 'Ghana' 'Guinea' 'Kenya' 'Lesotho' 'Liberia'
#  'Madagascar' 'Malawi' 'Mali' 'Mauritania' 'Mauritius' 'Mozambique'
#  'Namibia' 'Niger' 'Rwanda' 'Senegal' 'Seychelles' 'Sierra Leone'
#  'Somalia' 'Togo' 'Uganda' 'Zambia' 'Zimbabwe']

# %%
#Masking countries with out target variabe
df_nu=df[null_mask]
df_nu.head()
# Out:
#     Unnamed: 0             Region       Country  Year  Gender  \
# 36          56  SDG: Central Asia    Tajikistan  2021  female
# 37          57  SDG: Central Asia    Tajikistan  2021    male
# 38          58  SDG: Central Asia    Tajikistan  2022  female
# 39          59  SDG: Central Asia    Tajikistan  2022    male
# 58          78  SDG: Central Asia  Turkmenistan  2022  female
#
#     Completion rate, lower secondary education,  \
# 36                                          NaN
# 37                                          NaN
# 38                                          NaN
# 39                                          NaN
# 58                                          NaN
#
#     Gross enrolment ratio, early childhood education,  \
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 58                                                NaN
#
#     Gross enrolment ratio, early childhood educational development programmes,  \
# 36                                                0.0
# 37                                                0.0
# 38                                                0.0
# 39                                                0.0
# 58                                                NaN
#
#     Gross intake ratio to the last grade of lower secondary general education,  \
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 58                                                0.0
#
#     Literacy rate, population 25-64 years,  \
# 36                                     NaN
# 37                                     NaN
# 38                                     NaN
# 39                                     NaN
# 58                                     NaN
#
#     Percentage of children under 5 years experiencing positive and stimulating home learning environments,  \
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 58                                                NaN
#
#     Percentage of students in lower secondary education who have their first or home language as language of instruction,  \
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 58                                                NaN
#
#     Percentage of teachers in lower secondary education who received in-service training in the last 12 months by type of training,  \
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 58                                                NaN
#
#     Teacher attrition rate from lower secondary education,  \
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 58                                                NaN
#
#     Existence of funding mechanisms to reallocate education resources to disadvantaged populations  \
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 58                                                NaN
#
#     Expenditure on education as a percentage of total government expenditure (%)  \
# 36                                              19.91
# 37                                              19.91
# 38                                              18.75
# 39                                              18.75
# 58                                                NaN
#
#     Government expenditure on education as a percentage of GDP (%)
# 36                                               5.66
# 37                                               5.66
# 38                                                NaN
# 39                                                NaN
# 58                                                NaN

# %%
mask= df2['Completion rate, lower secondary education,'].notna()
#carving out those coutries that didn't have values for the target variable

# %%
df3= df2[mask]

# %%
round((df3.isnull().sum()/len(df3) *100), 2)
# Out:
# Unnamed: 0                                                                                                                          0.00
# Region                                                                                                                              0.00
# Country                                                                                                                             0.00
# Year                                                                                                                                0.00
# Gender                                                                                                                              0.00
# Completion rate, lower secondary education,                                                                                         0.00
# Gross enrolment ratio, early childhood education,                                                                                  36.11
# Gross enrolment ratio, early childhood educational development programmes,                                                         17.31
# Gross intake ratio to the last grade of lower secondary general education,                                                         36.27
# Literacy rate, population 25-64 years,                                                                                             73.93
# Percentage of children under 5 years experiencing positive and stimulating home learning environments,                             94.02
# Percentage of students in lower secondary education who have their first or home language as language of instruction,              93.59
# Percentage of teachers in lower secondary education who received in-service training in the last 12 months by type of training,    95.62
# Teacher attrition rate from lower secondary education,                                                                             94.98
# Existence of funding mechanisms to reallocate education resources to disadvantaged populations                                     93.80
# Expenditure on education as a percentage of total government expenditure (%)                                                       20.62
# Government expenditure on education as a percentage of GDP (%)                                                                     15.71
# dtype: float64

# %% [markdown]
# Now, all the dataset has values for the target variables, however they are still some missing values

# %%
round((df3.isnull().sum()/len(df3) *100), 2).plot(kind='bar')
# Out:
# <Axes: >

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'Region', 'Country', 'Year', 'Gender',
#        'Completion rate, lower secondary education,',
#        'Gross enrolment ratio, early childhood education,',
#        'Gross enrolment ratio, early childhood educational development programmes,',
#        'Gross intake ratio to the last grade of lower secondary general education,',
#        'Literacy rate, population 25-64 years,',
#        'Percentage of children under 5 years experiencing positive and stimulating home learning environments,',
#        'Percentage of students in lower secondary education who have their first or home language as language of instruction,',
#        'Percentage of teachers in lower secondary education who received in-service training in the last 12 months by type of training,',
#        'Teacher attrition rate from lower secondary education,',
#        'Existence of funding mechanisms to reallocate education resources to disadvantaged populations',
#        'Expenditure on education as a percentage of total government expenditure (%)',
#        'Government expenditure on education as a percentage of GDP (%)'],
#       dtype='object')

# %% [markdown]
# Droping columns that has more than 90% missing values

# %%
df4= df3.drop(columns=[
       'Percentage of children under 5 years experiencing positive and stimulating home learning environments,',
       'Percentage of students in lower secondary education who have their first or home language as language of instruction,',
       'Percentage of teachers in lower secondary education who received in-service training in the last 12 months by type of training,',
        'Teacher attrition rate from lower secondary education,',
       'Existence of funding mechanisms to reallocate education resources to disadvantaged populations'])

# %%
print('The shape of is :', df4.shape)
round((df4.isnull().sum()/len(df3) *100), 2)
# Out:
# The shape of is : (1872, 12)
# Unnamed: 0                                                                       0.00
# Region                                                                           0.00
# Country                                                                          0.00
# Year                                                                             0.00
# Gender                                                                           0.00
# Completion rate, lower secondary education,                                      0.00
# Gross enrolment ratio, early childhood education,                               36.11
# Gross enrolment ratio, early childhood educational development programmes,      17.31
# Gross intake ratio to the last grade of lower secondary general education,      36.27
# Literacy rate, population 25-64 years,                                          73.93
# Expenditure on education as a percentage of total government expenditure (%)    20.62
# Government expenditure on education as a percentage of GDP (%)                  15.71
# dtype: float64

# %%
round((df4.isnull().sum()/len(df3) *100), 2).plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# **Analysing "Literacy rate, population 25-64 years futher**

# %%
mask_literacy= df4["Literacy rate, population 25-64 years,"].notna()
df5= df4[mask_literacy]
df5.head()
# Out:
#     Unnamed: 0                          Region     Country  Year  Gender  \
# 16          16               SDG: Central Asia  Kazakhstan  2020  female
# 17          17               SDG: Central Asia  Kazakhstan  2020    male
# 78          98               SDG: Central Asia  Uzbekistan  2021  female
# 79          99               SDG: Central Asia  Uzbekistan  2021    male
# 96         116  SDG: Central and Southern Asia  Kazakhstan  2020  female
#
#     Completion rate, lower secondary education,  \
# 16                                        99.90
# 17                                        99.70
# 78                                        99.06
# 79                                        99.06
# 96                                        99.90
#
#     Gross enrolment ratio, early childhood education,  \
# 16                                              55.76
# 17                                              56.28
# 78                                              43.36
# 79                                              44.63
# 96                                              55.76
#
#     Gross enrolment ratio, early childhood educational development programmes,  \
# 16                                              28.22
# 17                                              27.99
# 78                                               0.00
# 79                                               0.00
# 96                                              28.22
#
#     Gross intake ratio to the last grade of lower secondary general education,  \
# 16                                             103.86
# 17                                             104.18
# 78                                                NaN
# 79                                                NaN
# 96                                             103.86
#
#     Literacy rate, population 25-64 years,  \
# 16                                    99.8
# 17                                    99.9
# 78                                   100.0
# 79                                   100.0
# 96                                    99.8
#
#     Expenditure on education as a percentage of total government expenditure (%)  \
# 16                                              20.16
# 17                                              20.16
# 78                                              21.43
# 79                                              21.43
# 96                                              20.16
#
#     Government expenditure on education as a percentage of GDP (%)
# 16                                               4.45
# 17                                               4.45
# 78                                               4.62
# 79                                               4.62
# 96                                               4.45

# %%
df5.corr()
# Out:
# <ipython-input-18-d0269aa5c0fc>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df5.corr()
#                                                     Unnamed: 0      Year  \
# Unnamed: 0                                            1.000000 -0.129481
# Year                                                 -0.129481  1.000000
# Completion rate, lower secondary education,          -0.485805  0.224658
# Gross enrolment ratio, early childhood education,    -0.385273  0.176016
# Gross enrolment ratio, early childhood educatio...   -0.251952  0.091780
# Gross intake ratio to the last grade of lower s...   -0.473130  0.268103
# Literacy rate, population 25-64 years,               -0.392032  0.189510
# Expenditure on education as a percentage of tot...    0.152724 -0.132468
# Government expenditure on education as a percen...    0.089841 -0.019097
#
#                                                     Completion rate, lower secondary education,  \
# Unnamed: 0                                                                            -0.485805
# Year                                                                                   0.224658
# Completion rate, lower secondary education,                                            1.000000
# Gross enrolment ratio, early childhood education,                                      0.362944
# Gross enrolment ratio, early childhood educatio...                                     0.299892
# Gross intake ratio to the last grade of lower s...                                     0.896791
# Literacy rate, population 25-64 years,                                                 0.801837
# Expenditure on education as a percentage of tot...                                    -0.041894
# Government expenditure on education as a percen...                                     0.293596
#
#                                                     Gross enrolment ratio, early childhood education,  \
# Unnamed: 0                                                                                  -0.385273
# Year                                                                                         0.176016
# Completion rate, lower secondary education,                                                  0.362944
# Gross enrolment ratio, early childhood education,                                            1.000000
# Gross enrolment ratio, early childhood educatio...                                           0.225460
# Gross intake ratio to the last grade of lower s...                                           0.390223
# Literacy rate, population 25-64 years,                                                       0.378693
# Expenditure on education as a percentage of tot...                                          -0.198486
# Government expenditure on education as a percen...                                           0.088557
#
#                                                     Gross enrolment ratio, early childhood educational development programmes,  \
# Unnamed: 0                                                                                  -0.251952
# Year                                                                                         0.091780
# Completion rate, lower secondary education,                                                  0.299892
# Gross enrolment ratio, early childhood education,                                            0.225460
# Gross enrolment ratio, early childhood educatio...                                           1.000000
# Gross intake ratio to the last grade of lower s...                                           0.381829
# Literacy rate, population 25-64 years,                                                       0.329893
# Expenditure on education as a percentage of tot...                                           0.030806
# Government expenditure on education as a percen...                                           0.238343
#
#                                                     Gross intake ratio to the last grade of lower secondary general education,  \
# Unnamed: 0                                                                                  -0.473130
# Year                                                                                         0.268103
# Completion rate, lower secondary education,                                                  0.896791
# Gross enrolment ratio, early childhood education,                                            0.390223
# Gross enrolment ratio, early childhood educatio...                                           0.381829
# Gross intake ratio to the last grade of lower s...                                           1.000000
# Literacy rate, population 25-64 years,                                                       0.739043
# Expenditure on education as a percentage of tot...                                          -0.070322
# Government expenditure on education as a percen...                                           0.312740
#
#                                                     Literacy rate, population 25-64 years,  \
# Unnamed: 0                                                                       -0.392032
# Year                                                                              0.189510
# Completion rate, lower secondary education,                                       0.801837
# Gross enrolment ratio, early childhood education,                                 0.378693
# Gross enrolment ratio, early childhood educatio...                                0.329893
# Gross intake ratio to the last grade of lower s...                                0.739043
# Literacy rate, population 25-64 years,                                            1.000000
# Expenditure on education as a percentage of tot...                                0.061738
# Government expenditure on education as a percen...                                0.394815
#
#                                                     Expenditure on education as a percentage of total government expenditure (%)  \
# Unnamed: 0                                                                                   0.152724
# Year                                                                                        -0.132468
# Completion rate, lower secondary education,                                                 -0.041894
# Gross enrolment ratio, early childhood education,                                           -0.198486
# Gross enrolment ratio, early childhood educatio...                                           0.030806
# Gross intake ratio to the last grade of lower s...                                          -0.070322
# Literacy rate, population 25-64 years,                                                       0.061738
# Expenditure on education as a percentage of tot...                                           1.000000
# Government expenditure on education as a percen...                                           0.525940
#
#                                                     Government expenditure on education as a percentage of GDP (%)
# Unnamed: 0                                                                                   0.089841
# Year                                                                                        -0.019097
# Completion rate, lower secondary education,                                                  0.293596
# Gross enrolment ratio, early childhood education,                                            0.088557
# Gross enrolment ratio, early childhood educatio...                                           0.238343
# Gross intake ratio to the last grade of lower s...                                           0.312740
# Literacy rate, population 25-64 years,                                                       0.394815
# Expenditure on education as a percentage of tot...                                           0.525940
# Government expenditure on education as a percen...                                           1.000000

# %%
df4.head()
# Out:
#    Unnamed: 0             Region     Country  Year  Gender  \
# 0           0  SDG: Central Asia  Kazakhstan  2012  female
# 1           1  SDG: Central Asia  Kazakhstan  2012    male
# 2           2  SDG: Central Asia  Kazakhstan  2013  female
# 3           3  SDG: Central Asia  Kazakhstan  2013    male
# 4           4  SDG: Central Asia  Kazakhstan  2014  female
#
#    Completion rate, lower secondary education,  \
# 0                                         99.6
# 1                                         99.3
# 2                                         99.6
# 3                                         99.4
# 4                                         99.6
#
#    Gross enrolment ratio, early childhood education,  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              36.65
#
#    Gross enrolment ratio, early childhood educational development programmes,  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    Gross intake ratio to the last grade of lower secondary general education,  \
# 0                                              96.64
# 1                                              97.66
# 2                                             103.13
# 3                                             102.95
# 4                                             105.74
#
#    Literacy rate, population 25-64 years,  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    Expenditure on education as a percentage of total government expenditure (%)  \
# 0                                              19.25
# 1                                              19.25
# 2                                              17.96
# 3                                              17.96
# 4                                              17.32
#
#    Government expenditure on education as a percentage of GDP (%)
# 0                                               3.90
# 1                                               3.90
# 2                                               3.44
# 3                                               3.44
# 4                                               3.42

# %%
#df4[["Completion rate, lower secondary education", " Literacy rate, population 25-64 years"]]

# %%
df4["Literacy rate, population 25-64 years,"].describe()
# Out:
# count    488.000000
# mean      81.003730
# std       21.667577
# min        8.640000
# 25%       68.735000
# 50%       91.135000
# 75%       96.212500
# max      100.000000
# Name: Literacy rate, population 25-64 years,, dtype: float64

# %% [markdown]
# afr looking at the decsrition of the columns, i think it will be better we filled the missing values with the 25 percentile

# %%
df4["Gross enrolment ratio, early childhood education,"].describe()
#Analyzing the Gross enrolment ratio, early childhood education, column
# Out:
# count    1196.000000
# mean       47.379975
# std        28.894113
# min         0.720000
# 25%        23.135000
# 50%        43.860000
# 75%        68.777500
# max       160.860000
# Name: Gross enrolment ratio, early childhood education,, dtype: float64

# %%
df4["Gross enrolment ratio, early childhood educational development programmes,"].describe()
#Analyzing the "Gross enrolment ratio, early childhood educational development programmes, column
# Out:
# count    1548.000000
# mean        5.868056
# std        15.009822
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.305000
# max        93.540000
# Name: Gross enrolment ratio, early childhood educational development programmes,, dtype: float64

# %%
df4["Literacy rate, population 25-64 years,"] = df4["Literacy rate, population 25-64 years,"].fillna(df4["Literacy rate, population 25-64 years,"].quantile(0.25))
df4["Gross enrolment ratio, early childhood education,"] =df4["Gross enrolment ratio, early childhood education,"].fillna(df4["Gross enrolment ratio, early childhood education,"].mean)
df4["Expenditure on education as a percentage of total government expenditure (%)"] = df4["Expenditure on education as a percentage of total government expenditure (%)"].fillna(df4["Expenditure on education as a percentage of total government expenditure (%)"].mean())
df4["Government expenditure on education as a percentage of GDP (%)"] = df4["Government expenditure on education as a percentage of GDP (%)"].fillna(df4["Government expenditure on education as a percentage of GDP (%)"].mean())
df4["Gross enrolment ratio, early childhood education,"] =df4["Gross enrolment ratio, early childhood education,"].fillna(df4["Gross enrolment ratio, early childhood education,"].mean)
df4["Gross intake ratio to the last grade of lower secondary general education,"] = df4["Gross intake ratio to the last grade of lower secondary general education,"].fillna(df4["Gross intake ratio to the last grade of lower secondary general education,"].mean())

# %%
print("The shape of the dataset is :", df4.shape)
round((df4.isnull().sum()/len(df3) *100), 2)
# Out:
# The shape of the dataset is : (1872, 12)
# Unnamed: 0                                                                      0.0
# Region                                                                          0.0
# Country                                                                         0.0
# Year                                                                            0.0
# Gender                                                                          0.0
# Completion rate, lower secondary education,                                     0.0
# Gross enrolment ratio, early childhood education,                               0.0
# Gross enrolment ratio, early childhood educational development programmes,      0.0
# Gross intake ratio to the last grade of lower secondary general education,      0.0
# Literacy rate, population 25-64 years,                                          0.0
# Expenditure on education as a percentage of total government expenditure (%)    0.0
# Government expenditure on education as a percentage of GDP (%)                  0.0
# dtype: float64

# %% [markdown]
# **Renaming the columns**

# %%
new_column_names = {'Completion rate, lower secondary education,': 'Completion Rate for Primary Edu',
                    'Gross enrolment ratio, early childhood education,': 'Childhood Education GER',
                    'Gross enrolment ratio, early childhood educational development programmes,': 'Gross enrolment ratio, early childhood educational development programmes',
                    'Gross intake ratio to the last grade of primary education': 'Last Grade Primary Edu GIR',
                    'Literacy rate, population 25-64 years,': 'Literacy rate for 25-64 years old'
                    }

df4.rename(columns=new_column_names, inplace=True)

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'Region', 'Country', 'Year', 'Gender',
#        'Completion Rate for Primary Edu', 'Childhood Education GER',
#        'Gross enrolment ratio, early childhood educational development programmes',
#        'Gross intake ratio to the last grade of lower secondary general education,',
#        'Literacy rate for 25-64 years old',
#        'Expenditure on education as a percentage of total government expenditure (%)',
#        'Government expenditure on education as a percentage of GDP (%)'],
#       dtype='object')

# %%
df4.head()
# Out:
#    Unnamed: 0             Region     Country  Year  Gender  \
# 0           0  SDG: Central Asia  Kazakhstan  2012  female
# 1           1  SDG: Central Asia  Kazakhstan  2012    male
# 2           2  SDG: Central Asia  Kazakhstan  2013  female
# 3           3  SDG: Central Asia  Kazakhstan  2013    male
# 4           4  SDG: Central Asia  Kazakhstan  2014  female
#
#    Completion Rate for Primary Edu  \
# 0                             99.6
# 1                             99.3
# 2                             99.6
# 3                             99.4
# 4                             99.6
#
#                              Childhood Education GER  \
# 0  <bound method NDFrame._add_numeric_operations....
# 1  <bound method NDFrame._add_numeric_operations....
# 2  <bound method NDFrame._add_numeric_operations....
# 3  <bound method NDFrame._add_numeric_operations....
# 4                                              36.65
#
#    Gross enrolment ratio, early childhood educational development programmes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    Gross intake ratio to the last grade of lower secondary general education,  \
# 0                                              96.64
# 1                                              97.66
# 2                                             103.13
# 3                                             102.95
# 4                                             105.74
#
#    Literacy rate for 25-64 years old  \
# 0                             68.735
# 1                             68.735
# 2                             68.735
# 3                             68.735
# 4                             68.735
#
#    Expenditure on education as a percentage of total government expenditure (%)  \
# 0                                              19.25
# 1                                              19.25
# 2                                              17.96
# 3                                              17.96
# 4                                              17.32
#
#    Government expenditure on education as a percentage of GDP (%)
# 0                                               3.90
# 1                                               3.90
# 2                                               3.44
# 3                                               3.44
# 4                                               3.42

# %%
df 4.to_csv('Preprocessed Primary Edu.csv', index=False)
#Saving the data
